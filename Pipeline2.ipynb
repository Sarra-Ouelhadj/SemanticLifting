# %% [markdown]
# ### Provide required inputs

# %% [markdown]
# 1. the schema
# 2. its compling dataset

# %%
schema = "./Examples/Charging_Stations/schema.json"
dataset = "./Examples/Charging_Stations/data.csv"

# %% [markdown]
# ### Import the right extractor according to provided inputs

# %% [markdown]
# Presently, we propose two extractors:
# 1. read_jsonSchema_geojsonData
# 2. read_tableSchema_csvData

# %%
from library.read import read_tableSchema_csvData

# %% [markdown]
# From here, we start the **ETL** process:
# 1. **E**xtract
# 2. **T**ransform
# 3. **L**oad

# %% [markdown]
# ### 1. Extractor: Bundle graph initialisation

# %%
b0 = read_tableSchema_csvData(schema, dataset, "id_station_local", "station")

# %% [markdown]
# ##### Overview of the Global Semantic Model

# %%
b0.show_semantic_model(True)

# %% [markdown]
# ### 2. Transformers

# %% [markdown]
# In this example, we apply two transformers:
# 1. split
# 2. apply

# %% [markdown]
# #### 2.1 Split transformer

# %% [markdown]
# We apply the `split` transformer on the *Station* class bundle with:
# - instances class identifier: *nom_operateur*
# - attributes:
#     - *contact_operateur*
#     - *telephone_operateur*
# - name of the new bundle [optional]: *operateur*

# %%
b1 = b0.split(class_id= "nom_operateur", class_attributes=["contact_operateur","telephone_operateur"], new_class_name="operateur")

# %% [markdown]
# ##### Overview of the Global Semantic Model after `split` transformer

# %% [markdown]
# We apply `show_semantic_model` on the root bundle with `deep = True` to show the entire model

# %%
b0.show_semantic_model(True)

# %% [markdown]
# ##### Overview of the *Station* dataset

# %%
b0.dataset
# Out:
#        nom_operateur id_station_local  \
# 0   Borneco | FR*BHM           756453
# 1   Borneco | FR*BHM           756453
# 2   Borneco | FR*BHM           767307
# 3   Borneco | FR*BHM           767307
# 4   Borneco | FR*BHM           782313
# ..               ...              ...
# 95    evZen | FR*EVZ           377778
# 96    evZen | FR*EVZ           377796
# 97    evZen | FR*EVZ           377796
# 98    evZen | FR*EVZ           612871
# 99    evZen | FR*EVZ           612871
#
#                                           nom_station implantation_station  \
# 0                    BornEco/63dcef1cde530c3ec2928c1e               Voirie
# 1                    BornEco/63dcef1cde530c3ec2928c1e               Voirie
# 2                    BornEco/63dcefa3de530c3ec2928c39               Voirie
# 3                    BornEco/63dcefa3de530c3ec2928c39               Voirie
# 4                    BornEco/64255ebeceade60b493082cc               Voirie
# ..                                                ...                  ...
# 95  CARF - Bornes Publiques/8C44E3B4-E0FC-406A-A25...       Parking public
# 96  CARF - Bornes Publiques/8CF2C967-C80C-4463-B4B...       Parking public
# 97  CARF - Bornes Publiques/8CF2C967-C80C-4463-B4B...       Parking public
# 98  CARF - Bornes Publiques/97BBD38A-F72F-4418-916...       Parking public
# 99  CARF - Bornes Publiques/97BBD38A-F72F-4418-916...       Parking public
#
#                                       adresse_station geometry
# 0   3  Place Maurice de Sully, Sully-sur-Loire  45...     None
# 1   3  Place Maurice de Sully, Sully-sur-Loire  45...     None
# 2     Place des Jeux, Donnemarie-Dontilly  77520  ...     None
# 3     Place des Jeux, Donnemarie-Dontilly  77520  ...     None
# 4        38  Avenue de New York, Paris  75116  France     None
# ..                                                ...      ...
# 95     50  Promenade de la Mer, Menton  06500  France     None
# 96    Avenue de la Paix, Roquebrune-Cap-Martin  06...     None
# 97    Avenue de la Paix, Roquebrune-Cap-Martin  06...     None
# 98    Promenade du Maréchal Leclerc de Hautecloque...     None
# 99    Promenade du Maréchal Leclerc de Hautecloque...     None
#
# [100 rows x 6 columns]

# %% [markdown]
# ##### Overview of the *operateur* Semantic Model

# %%
b1.show_semantic_model(True) # deep = True or deep = False has no impact here

# %% [markdown]
# ##### Overview of the *operateur* dataset

# %%
b1.dataset
# Out:
#        nom_operateur            contact_operateur telephone_operateur
# 0   Borneco | FR*BHM  technique.borneco@gmail.com         33123456789
# 1   Borneco | FR*BHM  technique.borneco@gmail.com         33123456789
# 2   Borneco | FR*BHM  technique.borneco@gmail.com         33123456789
# 3   Borneco | FR*BHM  technique.borneco@gmail.com         33123456789
# 4   Borneco | FR*BHM  technique.borneco@gmail.com         33123456789
# ..               ...                          ...                 ...
# 95    evZen | FR*EVZ            support@evzen.com         33123456789
# 96    evZen | FR*EVZ            support@evzen.com         33123456789
# 97    evZen | FR*EVZ            support@evzen.com         33123456789
# 98    evZen | FR*EVZ            support@evzen.com         33123456789
# 99    evZen | FR*EVZ            support@evzen.com         33123456789
#
# [100 rows x 3 columns]

# %% [markdown]
# #### 2.2 Apply transformer

# %%
import pandas as pd

# %% [markdown]
# Values of *adresse_station* column is composed of distinct information: street, locality, postalcode and country.
# We want to create a column (respectively an attribute) to each information to comply with schema.org ontology.
#
# Technically, we use `apply` transformer twice.
# 1. to split between the street and the rest of the address
# 2. to split the rest of the address

# %%
b0.apply(lambda x : pd.Series(x['adresse_station'].split(',')),{"adresse_rue": 'string', "adresse_ville_codepostal": 'string'})
b0.dataset
# Out:
#        nom_operateur id_station_local  \
# 0   Borneco | FR*BHM           756453
# 1   Borneco | FR*BHM           756453
# 2   Borneco | FR*BHM           767307
# 3   Borneco | FR*BHM           767307
# 4   Borneco | FR*BHM           782313
# ..               ...              ...
# 95    evZen | FR*EVZ           377778
# 96    evZen | FR*EVZ           377796
# 97    evZen | FR*EVZ           377796
# 98    evZen | FR*EVZ           612871
# 99    evZen | FR*EVZ           612871
#
#                                           nom_station implantation_station  \
# 0                    BornEco/63dcef1cde530c3ec2928c1e               Voirie
# 1                    BornEco/63dcef1cde530c3ec2928c1e               Voirie
# 2                    BornEco/63dcefa3de530c3ec2928c39               Voirie
# 3                    BornEco/63dcefa3de530c3ec2928c39               Voirie
# 4                    BornEco/64255ebeceade60b493082cc               Voirie
# ..                                                ...                  ...
# 95  CARF - Bornes Publiques/8C44E3B4-E0FC-406A-A25...       Parking public
# 96  CARF - Bornes Publiques/8CF2C967-C80C-4463-B4B...       Parking public
# 97  CARF - Bornes Publiques/8CF2C967-C80C-4463-B4B...       Parking public
# 98  CARF - Bornes Publiques/97BBD38A-F72F-4418-916...       Parking public
# 99  CARF - Bornes Publiques/97BBD38A-F72F-4418-916...       Parking public
#
#                                       adresse_station geometry  \
# 0   3  Place Maurice de Sully, Sully-sur-Loire  45...     None
# 1   3  Place Maurice de Sully, Sully-sur-Loire  45...     None
# 2     Place des Jeux, Donnemarie-Dontilly  77520  ...     None
# 3     Place des Jeux, Donnemarie-Dontilly  77520  ...     None
# 4        38  Avenue de New York, Paris  75116  France     None
# ..                                                ...      ...
# 95     50  Promenade de la Mer, Menton  06500  France     None
# 96    Avenue de la Paix, Roquebrune-Cap-Martin  06...     None
# 97    Avenue de la Paix, Roquebrune-Cap-Martin  06...     None
# 98    Promenade du Maréchal Leclerc de Hautecloque...     None
# 99    Promenade du Maréchal Leclerc de Hautecloque...     None
#
#                                        adresse_rue  \
# 0                        3  Place Maurice de Sully
# 1                        3  Place Maurice de Sully
# 2                                   Place des Jeux
# 3                                   Place des Jeux
# 4                           38  Avenue de New York
# ..                                             ...
# 95                         50  Promenade de la Mer
# 96                               Avenue de la Paix
# 97                               Avenue de la Paix
# 98    Promenade du Maréchal Leclerc de Hautecloque
# 99    Promenade du Maréchal Leclerc de Hautecloque
#
#                  adresse_ville_codepostal
# 0          Sully-sur-Loire  45600  France
# 1          Sully-sur-Loire  45600  France
# 2      Donnemarie-Dontilly  77520  France
# 3      Donnemarie-Dontilly  77520  France
# 4                    Paris  75116  France
# ..                                    ...
# 95                  Menton  06500  France
# 96   Roquebrune-Cap-Martin  06190  France
# 97   Roquebrune-Cap-Martin  06190  France
# 98                  Menton  06500  France
# 99                  Menton  06500  France
#
# [100 rows x 8 columns]

# %%
b0.show_semantic_model()

# %%
b0.apply(lambda x : pd.Series(re.findall('\S+', x['adresse_ville_codepostal'])),{"adresse_localite": 'string', "adresse_codepostal": 'string', "adresse_pays": 'string', 'col': 'string'})
b0.dataset
# Out:
#        nom_operateur id_station_local  \
# 0   Borneco | FR*BHM           756453
# 1   Borneco | FR*BHM           756453
# 2   Borneco | FR*BHM           767307
# 3   Borneco | FR*BHM           767307
# 4   Borneco | FR*BHM           782313
# ..               ...              ...
# 95    evZen | FR*EVZ           377778
# 96    evZen | FR*EVZ           377796
# 97    evZen | FR*EVZ           377796
# 98    evZen | FR*EVZ           612871
# 99    evZen | FR*EVZ           612871
#
#                                           nom_station implantation_station  \
# 0                    BornEco/63dcef1cde530c3ec2928c1e               Voirie
# 1                    BornEco/63dcef1cde530c3ec2928c1e               Voirie
# 2                    BornEco/63dcefa3de530c3ec2928c39               Voirie
# 3                    BornEco/63dcefa3de530c3ec2928c39               Voirie
# 4                    BornEco/64255ebeceade60b493082cc               Voirie
# ..                                                ...                  ...
# 95  CARF - Bornes Publiques/8C44E3B4-E0FC-406A-A25...       Parking public
# 96  CARF - Bornes Publiques/8CF2C967-C80C-4463-B4B...       Parking public
# 97  CARF - Bornes Publiques/8CF2C967-C80C-4463-B4B...       Parking public
# 98  CARF - Bornes Publiques/97BBD38A-F72F-4418-916...       Parking public
# 99  CARF - Bornes Publiques/97BBD38A-F72F-4418-916...       Parking public
#
#                                       adresse_station geometry  \
# 0   3  Place Maurice de Sully, Sully-sur-Loire  45...     None
# 1   3  Place Maurice de Sully, Sully-sur-Loire  45...     None
# 2     Place des Jeux, Donnemarie-Dontilly  77520  ...     None
# 3     Place des Jeux, Donnemarie-Dontilly  77520  ...     None
# 4        38  Avenue de New York, Paris  75116  France     None
# ..                                                ...      ...
# 95     50  Promenade de la Mer, Menton  06500  France     None
# 96    Avenue de la Paix, Roquebrune-Cap-Martin  06...     None
# 97    Avenue de la Paix, Roquebrune-Cap-Martin  06...     None
# 98    Promenade du Maréchal Leclerc de Hautecloque...     None
# 99    Promenade du Maréchal Leclerc de Hautecloque...     None
#
#                                        adresse_rue  \
# 0                        3  Place Maurice de Sully
# 1                        3  Place Maurice de Sully
# 2                                   Place des Jeux
# 3                                   Place des Jeux
# 4                           38  Avenue de New York
# ..                                             ...
# 95                         50  Promenade de la Mer
# 96                               Avenue de la Paix
# 97                               Avenue de la Paix
# 98    Promenade du Maréchal Leclerc de Hautecloque
# 99    Promenade du Maréchal Leclerc de Hautecloque
#
#                  adresse_ville_codepostal       adresse_localite  \
# 0          Sully-sur-Loire  45600  France        Sully-sur-Loire
# 1          Sully-sur-Loire  45600  France        Sully-sur-Loire
# 2      Donnemarie-Dontilly  77520  France    Donnemarie-Dontilly
# 3      Donnemarie-Dontilly  77520  France    Donnemarie-Dontilly
# 4                    Paris  75116  France                  Paris
# ..                                    ...                    ...
# 95                  Menton  06500  France                 Menton
# 96   Roquebrune-Cap-Martin  06190  France  Roquebrune-Cap-Martin
# 97   Roquebrune-Cap-Martin  06190  France  Roquebrune-Cap-Martin
# 98                  Menton  06500  France                 Menton
# 99                  Menton  06500  France                 Menton
#
#    adresse_codepostal adresse_pays  col
# 0               45600       France  NaN
# 1               45600       France  NaN
# 2               77520       France  NaN
# 3               77520       France  NaN
# 4               75116       France  NaN
# ..                ...          ...  ...
# 95              06500       France  NaN
# 96              06190       France  NaN
# 97              06190       France  NaN
# 98              06500       France  NaN
# 99              06500       France  NaN
#
# [100 rows x 12 columns]

# %%
b0.show_semantic_model()

# %% [markdown]
# We delete intermediate attributes that we don't want to take into consideration in output RDF data.

# %%
b0.delete_attribute("col")
b0.delete_attribute("adresse_ville_codepostal")

# %%
b0.show_semantic_model()

# %% [markdown]
# We annotate the created attributes according to schema.org, and document *operateur* class bundle and *Voirie* value of *implantation_station* enumeration bundle.

# %%
b0.annotate(attributes={"adresse_station":"https://schema.org/address","adresse_rue":"https://schema.org/streetAddress", "adresse_localite":"https://schema.org/addressLocality","adresse_codepostal":"https://schema.org/postalCode", "adresse_pays":"https://schema.org/addressCountry"})
b1.document(class_definition="L'opérateur est la personne qui exploite l'infrastructure de recharger pour le compte d'un aménageur dans le cadre d'un contrat ou pour son propre compte s'il est l'aménageur.")
dangling_bundles = b0.children()
dangling_bundles["implantation_station"].document(enum_values={"Voirie":"Aménagement et entretien des voies, des chemins ; administration publique qui s'occupe de l'ensemble des voies de communication."})
b0.show(True)
# Out:
# ------- Class -------
# name : Station
# IRI : None
# definition : None
# 	 ------- attributes -------
# 	 name : nom_operateur
# 	 IRI : None
# 	 definition : La dénomination sociale de l'opérateur. L'opérateur est la personne qui exploite l'infrastructure de recharger pour le compte d'un aménageur dans le cadre d'un contrat ou pour son propre compte s'il est l'aménageur. Vous pouvez accéder à cette dénomination exacte sur le site annuaire-entreprises.data.gouv.fr.
# 	 type : string
# 	 id : non
# 	 required : False
# 	 --------------
# 	 name : id_station_local
# 	 IRI : None
# 	 definition : Identifiant de la station utilisé localement. Si vous n'avez pas d'identifiant unique et que vous souhaitez en récupérer un, vous pouvez vous rendre sur https://heidi.app.etalab.studio. En cas de station qui n'est pas ouverte à l'itinérance, cet identifiant est indispensable.
# 	 type : string
# 	 id : oui
# 	 required : False
# 	 --------------
# 	 name : nom_station
# 	 IRI : None
# 	 definition : Le nom de la station.
# 	 type : string
# 	 id : non
# 	 required : True
# 	 --------------
# 	 name : adresse_station
# 	 IRI : https://schema.org/address
# 	 definition : L'adresse complète de la station : [numéro] [rue] [code postal] [ville].
# 	 type : string
# 	 id : non
# 	 required : True
# 	 --------------
# 	 name : adresse_rue
# 	 IRI : https://schema.org/streetAddress
# 	 definition : None
# 	 type : string
# 	 id : non
# 	 required : non
# 	 --------------
# 	 name : adresse_localite
# 	 IRI : https://schema.org/addressLocality
# 	 definition : None
# 	 type : string
# 	 id : non
# 	 required : non
# 	 --------------
# 	 name : adresse_codepostal
# 	 IRI : https://schema.org/postalCode
# 	 definition : None
# 	 type : string
# 	 id : non
# 	 required : non
# 	 --------------
# 	 name : adresse_pays
# 	 IRI : https://schema.org/addressCountry
# 	 definition : None
# 	 type : string
# 	 id : non
# 	 required : non
# 	 --------------
# ------- Links -------
# name : implantation_station
# IRI : None
# definition : Le type d'implantation de la station.
# Pour une station sur voirie, sélectionner "Voirie".
# Pour un parking public, (en ouvrage, en enclos, etc.), sélectionner "Parking public". Ces parkings sont généralement en gestion directe ou déléguée de la collectivité territoriale.
# Pour un parking privé à usage public / parking ouvert (ex: zone commerciale), sélectionner "Parking privé à usage public".
# Pour un parking réservé à la clientèle, aux usagers, sélectionnez "Parking privé réservé à la clientèle" (il s'agit d'un choix de l'aménageur public ou privé sur l'utilisation de son parking. Ex: hôtel, commerce, éventuellement certains bâtiments publics).
# Pour une station dédiée à la recharge rapide dont la durée d'utilisation est généralement limitée à la recharge principalement rapide et dont la première fonction de la station est la recharge et non le stationnement, sélectionner "Station dédiée à la recharge rapide" (ex : aires de service sur axes routiers, stations services, etc.).
# ------- Enumeration -------
# name : implantation_station
# IRI : None
# definition : Le type d'implantation de la station.
# Pour une station sur voirie, sélectionner "Voirie".
# Pour un parking public, (en ouvrage, en enclos, etc.), sélectionner "Parking public". Ces parkings sont généralement en gestion directe ou déléguée de la collectivité territoriale.
# Pour un parking privé à usage public / parking ouvert (ex: zone commerciale), sélectionner "Parking privé à usage public".
# Pour un parking réservé à la clientèle, aux usagers, sélectionnez "Parking privé réservé à la clientèle" (il s'agit d'un choix de l'aménageur public ou privé sur l'utilisation de son parking. Ex: hôtel, commerce, éventuellement certains bâtiments publics).
# Pour une station dédiée à la recharge rapide dont la durée d'utilisation est généralement limitée à la recharge principalement rapide et dont la première fonction de la station est la recharge et non le stationnement, sélectionner "Station dédiée à la recharge rapide" (ex : aires de service sur axes routiers, stations services, etc.).
# type : string
# required : True
# 	 ------- Values -------
# 	 name : Voirie
# 	 definition : Aménagement et entretien des voies, des chemins ; administration publique qui s'occupe de l'ensemble des voies de communication.
# 	 IRI : None
# 	 --------------
# 	 name : Parking public
# 	 definition : None
# 	 IRI : None
# 	 --------------
# 	 name : Parking privé à usage public
# 	 definition : None
# 	 IRI : None
# 	 --------------
# 	 name : Parking privé réservé à la clientèle
# 	 definition : None
# 	 IRI : None
# 	 --------------
# 	 name : Station dédiée à la recharge rapide
# 	 definition : None
# 	 IRI : None
# 	 --------------
# name : nom_operateur
# IRI : None
# definition : None
# ------- Class -------
# name : operateur
# IRI : None
# definition : L'opérateur est la personne qui exploite l'infrastructure de recharger pour le compte d'un aménageur dans le cadre d'un contrat ou pour son propre compte s'il est l'aménageur.
# 	 ------- attributes -------
# 	 name : nom_operateur
# 	 IRI : None
# 	 definition : La dénomination sociale de l'opérateur. L'opérateur est la personne qui exploite l'infrastructure de recharger pour le compte d'un aménageur dans le cadre d'un contrat ou pour son propre compte s'il est l'aménageur. Vous pouvez accéder à cette dénomination exacte sur le site annuaire-entreprises.data.gouv.fr.
# 	 type : string
# 	 id : oui
# 	 required : False
# 	 --------------
# 	 name : contact_operateur
# 	 IRI : None
# 	 definition : Adresse courriel de l'opérateur. Favoriser les adresses génériques de contact.
# 	 type : string
# 	 id : non
# 	 required : True
# 	 --------------
# 	 name : telephone_operateur
# 	 IRI : None
# 	 definition : Numéro de téléphone permettant de contacter l'opérateur.
# 	 type : string
# 	 id : non
# 	 required : False
# 	 --------------

# %% [markdown]
# ### 3. Loaders

# %% [markdown]
# Presently, we propose two loaders:
# 1. generateOntology
# 2. generateRDF

# %% [markdown]
# #### 3.1 Generate the ontology

# %%
g, kpi_results = b0.generateOntology(True)

# %% [markdown]
# ##### Overview of the generated ontology

# %%
kpi_results
# Out:
#                                                   IRI              type  \
# 0             https://data.grandlyon.com/onto/Station             Class
# 1        https://data.grandlyon.com/onto/nomOperateur  DatatypeProperty
# 2      https://data.grandlyon.com/onto/idStationLocal  DatatypeProperty
# 3          https://data.grandlyon.com/onto/nomStation  DatatypeProperty
# 4   https://data.grandlyon.com/onto/implantationSt...    ObjectProperty
# 5   https://data.grandlyon.com/vocab/Implantation_...     ConceptScheme
# 6             https://data.grandlyon.com/vocab/voirie           Concept
# 7     https://data.grandlyon.com/vocab/parking_public           Concept
# 8   https://data.grandlyon.com/vocab/parking_privé...           Concept
# 9   https://data.grandlyon.com/vocab/parking_privé...           Concept
# 10  https://data.grandlyon.com/vocab/station_dédié...           Concept
# 11       https://data.grandlyon.com/onto/nomOperateur    ObjectProperty
# 12          https://data.grandlyon.com/onto/Operateur             Class
# 13       https://data.grandlyon.com/onto/nomOperateur  DatatypeProperty
# 14   https://data.grandlyon.com/onto/contactOperateur  DatatypeProperty
# 15  https://data.grandlyon.com/onto/telephoneOpera...  DatatypeProperty
#
#                  related
# 0                     NA
# 1                Station
# 2                Station
# 3                Station
# 4                Station
# 5                     NA
# 6   implantation_station
# 7   implantation_station
# 8   implantation_station
# 9   implantation_station
# 10  implantation_station
# 11               Station
# 12                    NA
# 13             operateur
# 14             operateur
# 15             operateur

# %% [markdown]
# ##### Save the ontology in a file

# %%
with open("./results/onto.ttl", "w") as f:
    f.write(g.serialize(format="turtle"))

# %% [markdown]
# #### 3.2 Generate the RDF data

# %%
g_rdf = b0.generateRDF(True)

# %% [markdown]
# ##### Save the RDf data in a file

# %%
with open("./results/instances.ttl", "w") as f:
    f.write(g_rdf.serialize(format="turtle"))
